# %% [markdown]
# # Visualise Density

# %%
library(here)
# Out:
# here() starts at C:/Users/lhambrec/Sync/1_Projects/Simulator/DroneSurveySimulator

# %% [markdown]
# load data

# %%
# Set default figure size and resolution
options(repr.plot.width = 10, repr.plot.height = 8, repr.plot.res = 300)
wmu_number_list <- c('501', '503', '512', '517', '528')
wmu_number <- wmu_number_list[2]
# save DSM list
input_path <-  here("Output", "Density", paste0("density",wmu_number,".RData"))
load(file = input_path)

# %% [markdown]
# Plot density

# %%
#plot(density)
plot(density@density.surface[[1]]['density'])
# Out:
# Plot with title "density"

# %% [markdown]
# Model variance

# %%
print(paste0("Total abundance: ", total_abundance))
print(model_variance)
# Out:
# [1] "Total abundance: 14834.1301508506"
# Summary of uncertainty in a density surface model calculated
#  analytically for GAM, with delta method
#
# Approximate asymptotic confidence interval:
#     2.5%     Mean    97.5%
# 12796.19 14834.13 17196.64
# (Using log-Normal approximation)
#
# Point estimate                 : 14834.13
# CV of detection function       : 0.07289705
# CV from GAM                    : 0.0197
# Total standard error           : 1120.099
# Total coefficient of variation : 0.0755
